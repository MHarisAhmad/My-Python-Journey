# %%
import numpy as np

# %%
a = np.eye(3)
print(a)
b = np.eye(2)
print(b)

# %%
c = np.eye(2,3)
print(c)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]]

# %%
d = np.linspace(0,10, num = 5)
print(d)
# Out:
# [ 0.   2.5  5.   7.5 10. ]
