# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
b = a + 3
print(b)
# Out:
# [4 5 6 7]

# %%
c = np.array([1,2,3,4])
d = np.array([5,6,7,8])
add = c + d
print(add)
# Out:
# [ 6  8 10 12]

# %%
c = np.array([1,2,3,4])
d = np.array([5,6,7,8])
add = np.add(c,d)
print(add)
# Out:
# [ 6  8 10 12]

# %%
c = np.array([1,2,3,4])
d = np.array([5,6,7,8])
mul = c * d
print(mul)
# Out:
# [ 5 12 21 32]
