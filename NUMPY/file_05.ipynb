# %%
import numpy as np

# %%
a = np.random.rand(1,4)
print(a)
# Out:
# [[0.82411194 0.88169805 0.86127372 0.7293984 ]]

# %%
b = np.random.ranf((1,4))
print(b)
# Out:
# [[0.6280186  0.04809305 0.28430109 0.91238956]]

# %%
c = np.random.randn(2,3)
print(c)
# Out:
# [[-0.24152057 -0.08276947 -0.11466852]
#  [-0.88981789  0.09745601 -1.18169848]]

# %%
d = np.random.randint(1,4,5)
print(d)
# Out:
# [1 1 2 3 2]
