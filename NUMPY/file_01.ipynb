# %%
import numpy as np

# %%
a = np.array([1,2,3], dtype = "int16")
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[8.0,9.0,3.0],[1,2,3]])
print(b)
# Out:
# [[8. 9. 3.]
#  [1. 2. 3.]]

# %%
#get deimnesion
b.ndim
# Out:
# 2

# %%
#get shape
a.shape
# Out:
# (3,)

# %%
b.shape
# Out:
# (2, 3)

# %%
#et data-type
a.dtype
# Out:
# dtype('int16')

# %%
#get item-size
a.itemsize
# Out:
# 8

# %%
b = np.array([[1.0,2.0,3.0],[3.0,4.0,5.0]])
print(b)
# Out:
# [[1. 2. 3.]
#  [3. 4. 5.]]
