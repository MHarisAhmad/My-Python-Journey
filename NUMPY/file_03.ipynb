# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
a.shape
# Out:
# (3,)

# %%
b = []
for i in range(1,4):
    no = int(input("Enter: "))
    b.append(no)
print(b)
print(np.array(b))
print(type(b))
print(type(np.array(b)))
# Out:
# [1, 2, 3]
# [1 2 3]
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
c = np.zeros(3)
print(c)
# Out:
# [0. 0. 0.]

# %%
d = np.ones(5)
print(d)
# Out:
# [1. 1. 1. 1. 1.]

# %%
e = np.ones((2,4))
print(e)
# Out:
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]

# %%
f = np.arange(1,6)
print(f)
# Out:
# [1 2 3 4 5]

# %%
g = np.empty(2)
print(g)
# Out:
# [1.60221072e-306 1.66889282e-307]

# %%
ab = np.full((2,2), 3)
print(ab)
print()
bc = np.full_like(ab, 1)
print(bc)
# Out:
# [[3 3]
#  [3 3]]
#
# [[1 1]
#  [1 1]]
