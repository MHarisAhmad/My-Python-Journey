# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
a.shape

# %%
b = []
for i in range(1,4):
    no = int(input("Enter: "))
    b.append(no)
print(b)
print(np.array(b))
print(type(b))
print(type(np.array(b)))

# %%
c = np.zeros(3)
print(c)

# %%
d = np.ones(5)
print(d)

# %%
e = np.ones((2,4))
print(e)

# %%
f = np.arange(1,6)
print(f)

# %%
g = np.empty(2)
print(g)
