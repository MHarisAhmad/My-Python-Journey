# %%
import pandas as pd

# %%
a = pd.DataFrame(
    {
        "name": [
            "Haris",
            "Ahmad"
        ],
        "age": [18, 21]
    }
)
a
# Out:
#     name  age
# 0  Haris   18
# 1  Ahmad   21
